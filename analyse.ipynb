# %%
import pandas as pd

df = pd.read_csv("data/emissions.csv")

# add suffix to distinguish between quan and non-quant
suffix = "_quant"

# Add suffix to first and last entry in 'project_name'
df.loc[df.index[0], 'project_name'] += suffix  # First row
df.loc[df.index[-1], 'project_name'] += suffix  # Last row
df
# Out:
#              timestamp                                  project_name  \
# 0  2025-02-07T15:51:49  meta-llama/Llama-3.1-8B-Instruct_quant_quant
# 1  2025-02-07T16:10:49              meta-llama/Llama-3.1-8B-Instruct
# 2  2025-02-07T16:25:10              meta-llama/Llama-3.2-3B-Instruct
# 3  2025-02-07T16:44:35  meta-llama/Llama-3.2-3B-Instruct_quant_quant
#
#                                  run_id     duration  emissions  \
# 0  38f06b1a-c9e6-4c38-a55f-1b6cfb141527  1629.219631   0.034729
# 1  9cef8f5f-c729-40d8-b61e-4dd6927f5bd6  1096.720629   0.022913
# 2  2b6b87d0-3629-4a85-bee7-b3023a0fd837   815.982525   0.016465
# 3  f8d45203-4176-4e5d-914d-4dc56da04fee  1119.861177   0.022936
#
#    emissions_rate  cpu_power   gpu_power   ram_power  cpu_energy  ...  \
# 0        0.000021       42.5  223.128667  188.788404    0.019229  ...
# 1        0.000021       42.5  261.506038  188.788404    0.012944  ...
# 2        0.000020       42.5  196.346256  188.788404    0.009630  ...
# 3        0.000020       42.5  135.903192  188.788404    0.013217  ...
#
#    cpu_count                    cpu_model  gpu_count  \
# 0         16  Intel(R) Xeon(R) Gold 5415+          1
# 1         16  Intel(R) Xeon(R) Gold 5415+          1
# 2         16  Intel(R) Xeon(R) Gold 5415+          1
# 3         16  Intel(R) Xeon(R) Gold 5415+          1
#
#                    gpu_model longitude latitude  ram_total_size  \
# 0  1 x NVIDIA A100 80GB PCIe   12.5775   55.684      503.435745
# 1  1 x NVIDIA A100 80GB PCIe   12.5775   55.684      503.435745
# 2  1 x NVIDIA A100 80GB PCIe   12.5775   55.684      503.435745
# 3  1 x NVIDIA A100 80GB PCIe   12.5775   55.684      503.435745
#
#    tracking_mode on_cloud  pue
# 0        machine        N  1.0
# 1        machine        N  1.0
# 2        machine        N  1.0
# 3        machine        N  1.0
#
# [4 rows x 31 columns]
